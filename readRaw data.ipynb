# %%
import numpy as np
import pandas as pd
path='/Users/maxime/Documents/experiences/milli/MILLIDROP_manip/2017-10-11_CAABipy/EXP20171011_1635/'

file='Raw0012.raw'
dt = np.dtype([('time','<i4'),]+[(x, '<i2') for x in ['pmt1','pmt2','pmt3','pmt4','pmt5',
                                                     'ptd1','ptd2','ptd3','ptd4','ptd5',
                                                     'temperature']])       
data = pd.DataFrame(np.fromfile(path+file,dtype=dt))

# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(data.ptd2[0:1000])
plt.show()
sd=10000
plt.scatter(range(0,len(data.ptd2[-sd:])),data.ptd2[-sd:])
plt.show()

# %%
file='Raw0013.raw'
dt = np.dtype([('time','<i4'),]+[(x, '<i2') for x in ['pmt1','pmt2','pmt3','pmt4','pmt5',
                                                     'ptd1','ptd2','ptd3','ptd4','ptd5',
                                                     'temperature']])       
data = pd.DataFrame(np.fromfile(path+file,dtype=dt))

pt=data.ptd2.values
ptth=pt>2000
ptthcount=sum(ptth[1:]-ptth[:-1])
print(ptthcount/2)
print(data.shape)

plt.plot(ptth[0:10000])
plt.show()

# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(range(0,len(data.ptd2[:5000])),data.ptd2[0:5000])
plt.show()
sd=500
plt.scatter(range(0,len(data.ptd2[-sd:])),data.ptd2[-sd:])
plt.show()
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:9: DeprecationWarning: numpy boolean subtract, the `-` operator, is deprecated, use the bitwise_xor, the `^` operator, or the logical_xor function instead.
# 939.5
# (357048, 12)

# %%
path='/Users/maxime/Documents/experiences/milli/MILLIDROP_manip/2017-10-11_CAABipy/EXP20171011_1635/'
file='Raw0009.raw'
dt = np.dtype([('time','<i4'),]+[(x, '<i2') for x in ['pmt1','pmt2','pmt3','pmt4','pmt5',
                                                     'ptd1','ptd2','ptd3','ptd4','ptd5',
                                                     'temperature']])       
data = pd.DataFrame(np.fromfile(path+file,dtype=dt))
sd=500
plt.scatter(range(0,len(data.ptd2[-sd:])),data.ptd2[-sd:])
plt.show()
plt.scatter(range(0,len(data.ptd2[:sd])),data.ptd2[:sd])
plt.show()

# %%
data.ptd2[-10:-1]=0
sd=500
plt.scatter(range(0,len(data.ptd2[-sd:])),data.ptd2[-sd:])
plt.show()
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
data.values.tofile(path+file, sep="")
